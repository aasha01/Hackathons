# %%
import pandas as pd

# %%
sale = pd.read_csv("sales_train_validation.csv")

# %%
sale.head(20)
# Out:
#                                id        item_id    dept_id   cat_id store_id  \
# 0   HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1   HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2   HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3   HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4   HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
# 5   HOBBIES_1_006_CA_1_validation  HOBBIES_1_006  HOBBIES_1  HOBBIES     CA_1
# 6   HOBBIES_1_007_CA_1_validation  HOBBIES_1_007  HOBBIES_1  HOBBIES     CA_1
# 7   HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1
# 8   HOBBIES_1_009_CA_1_validation  HOBBIES_1_009  HOBBIES_1  HOBBIES     CA_1
# 9   HOBBIES_1_010_CA_1_validation  HOBBIES_1_010  HOBBIES_1  HOBBIES     CA_1
# 10  HOBBIES_1_011_CA_1_validation  HOBBIES_1_011  HOBBIES_1  HOBBIES     CA_1
# ...

# %%
sale.groupby(by=['state_id', 'store_id', 'cat_id', 'dept_id', 'item_id', 'id']).sum().stack()
# Out:
# state_id  store_id  cat_id     dept_id      item_id          id
# CA        CA_1      FOODS      FOODS_1      FOODS_1_001      FOODS_1_001_CA_1_validation      d_1       3
#                                                                                               d_2       0
#                                                                                               d_3       0
#                                                                                               d_4       1
#                                                                                               d_5       4
#                                                                                                        ..
# WI        WI_3      HOUSEHOLD  HOUSEHOLD_2  HOUSEHOLD_2_516  HOUSEHOLD_2_516_WI_3_validation  d_1909    0
#                                                                                               d_1910    0
# ...

# %%
sale.loc[sale['dept_id'] == 'HOBBIES' ]
# Out:
#                                   id        item_id    dept_id   cat_id  \
# 0      HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1      HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2      HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3      HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4      HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                              ...            ...        ...      ...
# 27852  HOBBIES_1_420_WI_3_validation  HOBBIES_1_420  HOBBIES_1  HOBBIES
# 27853  HOBBIES_1_421_WI_3_validation  HOBBIES_1_421  HOBBIES_1  HOBBIES
# 27854  HOBBIES_1_422_WI_3_validation  HOBBIES_1_422  HOBBIES_1  HOBBIES
# 27855  HOBBIES_1_423_WI_3_validation  HOBBIES_1_423  HOBBIES_1  HOBBIES
# 27856  HOBBIES_1_424_WI_3_validation  HOBBIES_1_424  HOBBIES_1  HOBBIES
#
#       store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  \
# ...

# %%
df.nunique()
# Out:
# id          30490
# item_id      3049
# dept_id         7
# cat_id          3
# store_id       10
#             ...
# d_1909         53
# d_1910         57
# d_1911         61
# d_1912         73
# d_1913         65
# Length: 1919, dtype: int64

# %%
df.shape
# Out:
# (30490, 1919)

# %%
df = pd.read_csv("BOOK.csv")

# %%
df
# Out:
#   id cat  d1  d2  d3
# 0  A   E   0   1   1
# 1  B   E   1   2   0
# 2  C   F   0   0   2
# 3  D   F   2   1   3

# %%
 df.groupby(by=['cat','id']).sum().stack().to_frame(name='freq')
# Out:
#            freq
# cat id
# E   A  d1     0
#        d2     1
#        d3     1
#     B  d1     1
#        d2     2
#        d3     0
# F   C  d1     0
#        d2     0
#        d3     2
#     D  d1     2
#        d2     1
#        d3     3

# %%
pd.melt(df,id_vars=['cat','id'])
# Out:
#    cat id variable  value
# 0    E  A       d1      0
# 1    E  B       d1      1
# 2    F  C       d1      0
# 3    F  D       d1      2
# 4    E  A       d2      1
# 5    E  B       d2      2
# 6    F  C       d2      0
# 7    F  D       d2      1
# 8    E  A       d3      1
# 9    E  B       d3      0
# 10   F  C       d3      2
# 11   F  D       d3      3

# %%
df.melt()
# Out:
#    variable  value
# 0      freq      0
# 1      freq      1
# 2      freq      1
# 3      freq      1
# 4      freq      2
# 5      freq      0
# 6      freq      0
# 7      freq      0
# 8      freq      2
# 9      freq      2
# 10     freq      1
# 11     freq      3
